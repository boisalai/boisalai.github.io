# %%
# How to merge two dictionaries
x = {'a': 1, 'b': 2}
y = {'b': 3, 'c': 4}
z = {**x, **y}
z
# Out:
# {'a': 1, 'b': 3, 'c': 4}

# %%
# Why Python Is Great:
# Function argument unpacking
def myfunc(x, y, z):
    print(x, y, z)

tuple_vec = (1, 0, 1)
dict_vec = {'x': 1, 'y': 0, 'z': 1}

print(myfunc(*tuple_vec))
print(myfunc(**dict_vec))
# Out:
# 1 0 1
# None
# 1 0 1
# None

# %%
# Python's list comprehension are awesome:
even_squares = [x * x for x in range(10) if not x % 2]
even_squares
# Out:
# [0, 4, 16, 36, 64]

# %%
import os
import sys

import matplotlib.pyplot as plt
import matplotlib as mpl
import pandas as pd
import numpy as np
import scipy as sp

# %%
def test1():
    msg = "Hello World"
    print(msg)
    print(os.listdir('.'))

    
test1()
# Out:
# Hello World
# ['hello.py', 'matplotlib_tutorial.ipynb', 'os_tutorial.ipynb', '.DS_Store', 'pytorch_03_neural_networks_tutorial.ipynb', 'tensorflow_modern.ipynb.txt', 'pytorch_12_linear_regression.ipynb', 'pytorch_04_cifar10_tutorial.ipynb', 'pytorch_00_tutorial.ipynb', 'tensor_tutorial.py', 'pytorch_11_pytorch_basics.ipynb', 'pytorch_02_autograd_tutorial.ipynb', 'setup.py', 'pytorch_15_feedforward_neural_network.ipynb', '.ipynb_checkpoints', 'model.ckpt', 'pytorch_16_convolutional_neural_network.ipynb', 'pytorch_14_logistic_regression.ipynb', 'seaborn_tutorial.ipynb', 'python_tutorial.ipynb', 'data', 'pytorch_01_tensor_tutorial.ipynb', 'pytorch_13_linear_regression.ipynb', 'tensorflow1.py']

# %%
print(sys.platform)
# Out:
# darwin

# %%
class Student(object):
    def __init__(self, name):
        self.name = name

        def set_age(self, age):
            self.age = age
        
        def set_major(self, major):
            self.major = major


def test3():
    anna = Student('anna')
    anna.set_age(21)
    anna.set_major('physics')

# %%
image = np.random.rand(30, 30)
plt.imshow(image, cmap=plt.cm.hot)
plt.colorbar()

# %%
x = np.linspace(0, 2, 200)
plt.plot(x, np.sin(x))
# plt.savefig("myfig.png")

# %%
print(os.getcwd())
# Out:
# /Users/boisalai/Documents/GitHub/boisalai.github.io/learning/2018_notebooks

# %%
print("Path at terminal when executing this file")
print(os.getcwd() + "\n")
# Out:
# Path at terminal when executing this file
# /Users/boisalai/Documents/GitHub/boisalai.github.io/learning/2018_notebooks

# %%
def test7():
    a = np.array([[4, 3, 5], [1, 2, 1]])
    print(a)
    b = np.sort(a, axis=1)
    print(b)

     
if __name__ == '__main__':
    # print_a() is only executed when the module is run directly.
    test7()
# Out:
# [[4 3 5]
#  [1 2 1]]
# [[3 4 5]
#  [1 1 2]]
